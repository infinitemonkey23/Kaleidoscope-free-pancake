# %%
import moviepy.editor as mpy
import moviepy
from PIL import Image, ImageDraw, ImageOps
import numpy as np
import gizeh as gz
from matplotlib.image import imread
# %matplotlib inline
from matplotlib import pyplot as plt

myclip = Image.open("1.jpg")
myclip = np.array(myclip)


def clipfilter(myclip,width,height):
    
    h,w,other= myclip.shape
#    center=  np.array([(12*w/22), h*0.38])
    center=np.array([width,height])
    
    userimportrot=0
 #   userimportrot=2*np.pi*(t/(d)) *1.03
    user_rota=(np.pi/6)+userimportrot
    def my_filter(get_frame):
        radi=200

        surface = gz.Surface(692,300)
        fill = (gz.ImagePattern(myclip, pixel_zero=center,extend="reflect")
                .scale(1, center=center))
        for (nfaces,angle,rot,pangle,flip) in ([3, np.pi/3, np.pi/2,-np.pi/3,0],
                                               [3, 0, np.pi/6,0,1],[3, -np.pi/3, -np.pi/6,np.pi/3,0]):

            xy = (346+(np.sin(pangle)*radi),0+(np.cos(pangle)*radi))
            shape = gz.regular_polygon(radi,nfaces,angle=rot, xy= xy,
                    fill=(fill.rotate(user_rota, center)).scale(1) )

      #      shape=gz.polyline(points=)
            if flip ==1:

                shape=shape.scale(-1,1,center=xy)
            shape.draw(surface)
         
    #        if flip ==1:
    #            fliplopper= lopper[:,::-1]

        newIm = Image.fromarray(surface.get_npimage(), "RGB")
    #   newIm.show()
    # ####   newIm.save("out.jpg")
      
        
        return(newIm)
    
    trapez=my_filter(myclip)
    #(.5+ .05*np.sin(2*np.pi)))
    #-np.pi/3#
    #xy = (400+(np.sin(rot)*offs), 250+(np.cos(rot)*offs))
    




    w,h = trapez.size
    canvas=Image.new("RGB",(w,h*2),color=0)
    canvas.paste(trapez,(0,h))

    flipped=ImageOps.flip(trapez)
    canvas.paste(flipped,(0,0))
    #canvas.show()
    #canvas.save("kal6.jpg")








    def hexaganalator(_image):
        w,h= _image.size
        hradius=2*h/3
        wradius=w/2
        my_canvas=gz.Surface(w*2,h*2)
        leftvert=(w/4)
        rightvert=(w*3/4)

        _image=np.array(_image)
        center=  np.array([(w/2), h/2])
        pattern=(gz.ImagePattern(_image,pixel_zero=(0,0)))
        hexs=[(w/2,h/2),(w/2,-h/2),(w/2,3*h/2),(-w/4,0),(5*w/4,0),(-w/4,h),(5*w/4,h)      ]
        for _sw, _sh in hexs:
            hex_pat = gz.polyline(points=[(leftvert,0), (rightvert,0), (w,h/2), (rightvert,h),
                                        (leftvert,h),(0,h/2),(leftvert,0)], stroke_width=0, fill=pattern,xy=(_sw,_sh))
            hex_pat.draw(my_canvas)
            outp= my_canvas.get_npimage()



        newIm = Image.fromarray(outp, "RGB")
        
#        newIm.save("fullpattern17.jpg")
        return(newIm)
    return(hexaganalator(canvas))
#clipfilter(myclip)

# %%
print(int(np.trunc((np.cos(np.pi/6))*2*200)))
# Out:
# 346

# %%
''' 
A program to create Kaleidoscopic images or videos from imported images or videos.
'''
import moviepy.editor as mpy
import moviepy
from PIL import Image, ImageDraw, ImageOps
import numpy as np
import gizeh as gz
from matplotlib.image import imread



class Stillkaleido:
    """
    Class representation of the function for creating a jpg kaleidoscope version of an image.
    """
    
    
    def __init__(self,openedim,rotated):
        '''
        initialize the file into a moviepy video.
        '''
        
        self.theimage = np.array(openedim)    
        
        self.radi=200
        ###for now##
        if rotated==False:
            self.rotation=(np.pi/6)
        else:
            self.rotation=(np.pi/6)+rotated
            
            
            
        
    def set_height_of_sub_im(self):
        """
        Changes the height of the image to be sected by user, for use in GUI
        """
        
        self.height_of_sub=height_of_sub
    
   # def rotate_sub_im(self, rotation_of_im):
    #    """
   #     changes the angle of the image selected by the user, for use in GUI
  #      """
        
 #       self.rotation=rotation_of_im+(np.pi/6)
        
    
 #   def set_back_colour(self,input_tuple):
           
   #     colour=x
        
        
        
        
    def Trianglize(self,center):
        self.centre=np.array([center])
        self.hori=(int(np.trunc((np.cos(np.pi/6))*2*200)))
        self.vert=int(self.radi*1.5)

        surface=gz.Surface(2*self.hori,self.vert,bg_color=(1, 1, 1))
        fill=(gz.ImagePattern(self.theimage, pixel_zero=center,extend="reflect")) 
        for (nfaces,angle,rot,pangle,flip) in ([3, np.pi/3, np.pi/2,-np.pi/3,0],
                                               [3, 0, np.pi/6,0,1],[3, -np.pi/3, -np.pi/6,np.pi/3,0]):
            xy = (self.hori+(np.sin(pangle)*self.radi),0+(np.cos(pangle)*self.radi))
            shape = gz.regular_polygon(self.radi,nfaces,angle=rot, xy= xy,
                    fill=(fill.rotate(self.rotation, center)).scale(1) )
            if flip ==1:
                shape=shape.scale(-1,1,center=xy)
            shape.draw(surface)  

        self.tring=Image.fromarray(surface.get_npimage(), "RGB")
     

        self.Trapeezer()
        return(self.Hexaganalator())
    
    
    def Trapeezer(self):
        
        mirrorcanva=Image.new("RGB",(2*self.hori,2*self.vert),color=0)
        mirrorcanva.paste(self.tring,(0,self.vert))
        flipped=ImageOps.flip(self.tring)
        mirrorcanva.paste(flipped,(0,0))
        
        self.tring=mirrorcanva
    
    
    def Hexaganalator(self):
   #     return(self.tring)
        maincanvas=gz.Surface(4*self.hori,4*self.vert)
        leftvert=(self.hori/2)
        rightvert=(3*self.hori/2)
        _image=np.array(self.tring)
        center=np.array([self.vert, self.hori])
        
        pattern=(gz.ImagePattern(_image,pixel_zero=(0,0)))
        hexs=[(self.hori,self.vert),(self.hori,-self.vert),(self.hori,3*self.vert),(-self.hori/2,0),
                                          (-self.hori/2,2*self.vert),(5*self.hori/2,0),(5*self.hori/2,2*self.vert)]
        for _sw, _sh in hexs:
            hex_pat = gz.polyline(points=[(leftvert,0), (rightvert,0), (2*self.hori,self.vert), (rightvert,2*self.vert),
                                          (leftvert,2*self.vert),(0,self.vert),(leftvert,0)], stroke_width=0, 
                                      fill=pattern,xy=(_sw,_sh))
            hex_pat.draw(maincanvas)
            outp= maincanvas.get_npimage()
        
        self.tring = Image.fromarray(outp, "RGB")
        return(self.tring)
    
    
    def saveimage(self,name):
        savename=name+".jpg"
        print(savename)
        self.tring.save(savename)

# %%
from tkinter.filedialog import askopenfilename
from tkinter import *
from PIL import Image, ImageDraw, ImageOps, ImageTk


class Window(Frame):
    
    def __init__(self,master=None):
        Frame.__init__(self,master)
        self.master=master
        self.init_window()
                  
    def init_window(self):
         
        self.started=False
        self.rotated=False
        self.master.title("Keleidoscopia")
        self.pack(fill=BOTH, expand=1)
                  
        mymenu=Menu(self.master)          
        self.master.config(menu=mymenu)
        
        file=Menu(mymenu)
        file.add_command(label="Open File",command=self.openfile)
        file.add_command(label="Select File",command=self.selectfile)
        file.add_command(label="Save Image",command=self.savefunc)
        mymenu.add_cascade(label="File",menu=file)
        
        edit=Menu(mymenu)

        edit.add_command(label="Show Text", command=self.showTxt)
  #      edit.add_command(label="Kaleidoscope", command=self.showversion)
        mymenu.add_cascade(label="Edit",menu=edit)
        
 

        
        self.mycanvas = Canvas(self.master,width=600,height=800,bd=2)
        self.mycanvas.pack(side=LEFT)
 

        self.slider = Scale(self.master, from_=-2*np.pi, to=2*np.pi, orient=HORIZONTAL, command=self.rotator,resolution = .1)
        self.slider.pack(side=LEFT)
        
        
         
    def selectfile(self):
        name = askopenfilename(initialdir="C:/Users/Tom/Documents/Python Scripts/Kaleidoscope/",
                           filetypes =(("jpeg files","*.jpg"),("All Files","*.*")),
                           title = "Choose a file.")
        self.filedir=(name)

        
    def openfile(self):
        self.myclip = Image.open(self.filedir)
        _intermediate=ImageTk.PhotoImage(self.myclip)
        self.myshownIm=_intermediate
        (w,h)= self.myclip.size

        
        
        self.mycanvas.create_image(0,0,image=self.myshownIm,anchor="nw")
     #   self.mycanvas.config(scrollregion=(0,0,w,h))     
        self.mycanvas.bind("<Button 1>",self.printcoords)
        
        self.my2canvas = Canvas(self.master,width=1500,height=1500,bd=2,)
        self.my2canvas.pack(side=RIGHT)
    
    def showversion(self):
        
        self.started=True
        self.trianglevers=Stillkaleido(self.myclip,self.rotated)
        self.imager=ImageTk.PhotoImage(self.trianglevers.Trianglize((self.x,self.y)))

        
        
        self.my2canvas.create_image(0,0,image=self.imager,anchor="nw")
        
    def rotator(self,event):
        print("!!!!!!")
        change=self.slider.get()
        self.rotated=change
        
        self.trianglevers=Stillkaleido(self.myclip,self.rotated)
        self.imager=ImageTk.PhotoImage(self.trianglevers.Trianglize((self.x,self.y)))
        
        self.my2canvas.create_image(0,0,image=self.imager,anchor="nw")
        
    def showTxt(self):
        text=Label(self,text="Wooop!, there it is!")
        text.pack()
        
        
    def client_exit(self):
        root.destroy()
        
        
    def printcoords(self,event):

        x = self.mycanvas.canvasx(event.x)
        y = self.mycanvas.canvasy(event.y)
        self.x=int(x)
        self.y=int(y)
        self.showversion()    
        
        
    def savefunc(self):
        name="trial3"
        self.trianglevers.saveimage(name)
    
        
root=Tk()
root.geometry("800x600")
app=Window(root)
root.mainloop()
# Out:
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!
# !!!!!!

# %%
w,h = trapez.size
canvas=Image.new("RGB",(w,h*2),color=255)
canvas.paste(trapez,(0,h))

flipped=ImageOps.flip(trapez)
canvas.paste(flipped,(0,0))
canvas.show()
#canvas.save("kal6.jpg")

# %%
def hexaganalator(_image):
    w,h= _image.size
    hradius=2*h/3
    wradius=w/2
    my_canvas=gz.Surface(w*2,h*2)
    leftvert=(w/4)
    rightvert=(w*3/4)
    
    _image=np.array(_image)
    center=  np.array([(w/2), h/2])
    pattern=(gz.ImagePattern(_image,pixel_zero=(0,0)))
    hexs=[(w/2,h/2),(w/2,-h/2),(w/2,3*h/2),(-w/4,0),(5*w/4,0),(-w/4,h),(5*w/4,h)      ]
    for _sw, _sh in hexs:
        hex_pat = gz.polyline(points=[(leftvert,0), (rightvert,0), (w,h/2), (rightvert,h),
                                    (leftvert,h),(0,h/2),(leftvert,0)], stroke_width=0, fill=pattern,xy=(_sw,_sh))
        hex_pat.draw(my_canvas)
        outp= my_canvas.get_npimage()
    
    
    
    newIm = Image.fromarray(outp, "RGB")
    newIm.show()
    newIm.save("fullpattern12.jpg")
hexaganalator(canvas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-259-62b3f528d210> in <module>
#      22     newIm.show()
#      23     newIm.save("fullpattern12.jpg")
# ---> 24 hexaganalator(canvas)
#
# <ipython-input-259-62b3f528d210> in hexaganalator(_image)
#       1 def hexaganalator(_image):
# ----> 2     w,h= _image.size
#       3     hradius=2*h/3
#       4     wradius=w/2
#       5     my_canvas=gz.Surface(w*2,h*2)
#
# TypeError: cannot unpack non-iterable method object

# %%
leftvert=(w/4)
rightvert=(w*3/4)
print(leftvert,rightvert,h)
# Out:
# 173.0 519.0 300

# %%
help(Canvas.config)
# Out:
# Help on function configure in module tkinter:
#
# configure(self, cnf=None, **kw)
#     Configure resources of a widget.
#
#     The values for resources are specified as keyword
#     arguments. To get an overview about
#     the allowed keyword arguments call the method keys.

# %%
import moviepy.editor as mpy
from PIL import Image, ImageDraw, ImageOps
import numpy as np
import gizeh as gz
from matplotlib.image import imread
# %matplotlib inline
from matplotlib import pyplot as plt

myclip = Image.open("1.jpg")

(h,w)= myclip.size
D=10

center=  np.array([(9*w/18), h*0.50])


def clipfilter(t):
    
    userimportrot=(t/6)*np.pi
    user_rota=np.pi/6+userimportrot
    def my_filter(t):
        radi=200

        surface = gz.Surface(692,300)
        fill = (gz.ImagePattern(myclip, pixel_zero=center,extend="reflect")
                .scale(1, center=center))
        for (nfaces,angle,rot,pangle,flip) in ([3, np.pi/3, np.pi/2,-np.pi/3,0],
                                               [3, 0, np.pi/6,0,1],[3, -np.pi/3, -np.pi/6,np.pi/3,0]):

            xy = (346+(np.sin(pangle)*radi),0+(np.cos(pangle)*radi))
            shape = gz.regular_polygon(radi,nfaces,angle=rot, xy= xy,
                    fill=(fill.rotate(user_rota, center)).scale(1) )

      #      shape=gz.polyline(points=)
            if flip ==1:

                shape=shape.scale(-1,1,center=xy)
            shape.draw(surface)
        lopper= surface.get_npimage()
    #        if flip ==1:
    #            fliplopper= lopper[:,::-1]

        newIm = Image.fromarray(lopper, "RGB")
    #   newIm.show()
    # ####   newIm.save("out.jpg")
      
        
        return(newIm)

    trapez=my_filter(t)
    #(.5+ .05*np.sin(2*np.pi)))
    #-np.pi/3#
    #xy = (400+(np.sin(rot)*offs), 250+(np.cos(rot)*offs))





    w,h = trapez.size
    canvas=Image.new("RGB",(w,h*2),color=0)
    canvas.paste(trapez,(0,h))

    flipped=ImageOps.flip(trapez)
    canvas.paste(flipped,(0,0))
    #canvas.show()
    #canvas.save("kal6.jpg")








    def hexaganalator(_image):
        w,h= _image.size
        hradius=2*h/3
        wradius=w/2
        my_canvas=gz.Surface(w*2,h*2)
        leftvert=(w/4)
        rightvert=(w*3/4)

        _image=np.array(_image)
        center=  np.array([(w/2), h/2])
        pattern=(gz.ImagePattern(_image,pixel_zero=(0,0)))
        hexs=[(w/2,h/2),(w/2,-h/2),(w/2,3*h/2),(-w/4,0),(5*w/4,0),(-w/4,h),(5*w/4,h)      ]
        for _sw, _sh in hexs:
            hex_pat = gz.polyline(points=[(leftvert,0), (rightvert,0), (w,h/2), (rightvert,h),
                                        (leftvert,h),(0,h/2),(leftvert,0)], stroke_width=0, fill=pattern,xy=(_sw,_sh))
            hex_pat.draw(my_canvas)
            outp= my_canvas.get_npimage()



        #newIm = Image.fromarray(outp, "RGB")
       # newIm.show()
       # newIm.save("fullpattern17.jpg")
        return(outp)
    return hexaganalator(canvas)
clip = mpy.VideoClip(clipfilter, duration=D)
clip.write_gif("madeclip.gif",fps=15, fuzz=10, opt="OptimizePlus")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-258-031a50e36d11> in <module>
#      98         return(outp)
#      99     return hexaganalator(canvas)
# --> 100 clip = mpy.VideoClip(clipfilter, duration=D)
#     101 clip.write_gif("madeclip.gif",fps=15, fuzz=10, opt="OptimizePlus")
#     102
#
# C:\ProgramData\Anaconda3\lib\site-packages\moviepy\video\VideoClip.py in __init__(self, make_frame, ismask, duration, has_constant_size)
#      84         if make_frame is not None:
#      85             self.make_frame = make_frame
# ---> 86             self.size = self.get_frame(0).shape[:2][::-1]
#      87         self.ismask = ismask
#      88         self.has_constant_size=has_constant_size
#
# <decorator-gen-135> in get_frame(self, t)
#
# C:\ProgramData\Anaconda3\lib\site-packages\moviepy\decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# C:\ProgramData\Anaconda3\lib\site-packages\moviepy\Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=None, keep_duration=True):
#
# <ipython-input-258-031a50e36d11> in clipfilter(t)
#      48         return(newIm)
#      49
# ---> 50     trapez=my_filter(t)
#      51     #(.5+ .05*np.sin(2*np.pi)))
#      52     #-np.pi/3#
#
# <ipython-input-258-031a50e36d11> in my_filter(t)
#      23
#      24         surface = gz.Surface(692,300)
# ---> 25         fill = (gz.ImagePattern(myclip, pixel_zero=center,extend="reflect")
#      26                 .scale(1, center=center))
#      27         for (nfaces,angle,rot,pangle,flip) in ([3, np.pi/3, np.pi/2,-np.pi/3,0],
#
# C:\ProgramData\Anaconda3\lib\site-packages\gizeh\gizeh.py in __init__(self, image, pixel_zero, filter, extend)
#     320             self._cairo_surface = image
#     321         else:
# --> 322             self._cairo_surface = Surface.from_image(image)._cairo_surface
#     323         self.matrix = translation_matrix(pixel_zero)
#     324         self.filter = filter
#
# C:\ProgramData\Anaconda3\lib\site-packages\gizeh\gizeh.py in from_image(image)
#      41     def from_image(image):
#      42         """Initialize the surface from an np array of an image."""
# ---> 43         h, w, d = image.shape
#      44         if d == 4:
#      45             image = image[:, :, [2, 1, 0, 3]]
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
###
fully wokring video version of program
###





import moviepy.editor as mpy
import moviepy
from PIL import Image, ImageDraw, ImageOps
import numpy as np
import gizeh as gz
from matplotlib.image import imread
# %matplotlib inline
from matplotlib import pyplot as plt

clip = mpy.VideoFileClip("jodoeye.gif")
clip=moviepy.video.fx.all.speedx(clip, factor=0.9)
clip=moviepy.video.fx.all.time_symmetrize(clip)
(h,w) ,d= clip.size,clip.duration



center=  np.array([(12*w/22), h*0.38])

def clipfilter(get_frame,t):
    
    userimportrot=0
 #   userimportrot=2*np.pi*(t/(d)) *1.03
    user_rota=(5*np.pi/6)+userimportrot
    def my_filter(get_frame):
        radi=200

        surface = gz.Surface(692,300)
        fill = (gz.ImagePattern(get_frame(t), pixel_zero=center,extend="reflect")
                .scale(1, center=center))
        for (nfaces,angle,rot,pangle,flip) in ([3, np.pi/3, np.pi/2,-np.pi/3,0],
                                               [3, 0, np.pi/6,0,1],[3, -np.pi/3, -np.pi/6,np.pi/3,0]):

            xy = (346+(np.sin(pangle)*radi),0+(np.cos(pangle)*radi))
            shape = gz.regular_polygon(radi,nfaces,angle=rot, xy= xy,
                    fill=(fill.rotate(user_rota, center)).scale(1) )

      #      shape=gz.polyline(points=)
            if flip ==1:

                shape=shape.scale(-1,1,center=xy)
            shape.draw(surface)
        lopper= surface.get_npimage()
    #        if flip ==1:
    #            fliplopper= lopper[:,::-1]

        newIm = Image.fromarray(lopper, "RGB")
    #   newIm.show()
    # ####   newIm.save("out.jpg")
      
        
        return(newIm)

    trapez=my_filter(get_frame)
    #(.5+ .05*np.sin(2*np.pi)))
    #-np.pi/3#
    #xy = (400+(np.sin(rot)*offs), 250+(np.cos(rot)*offs))





    w,h = trapez.size
    canvas=Image.new("RGB",(w,h*2),color=0)
    canvas.paste(trapez,(0,h))

    flipped=ImageOps.flip(trapez)
    canvas.paste(flipped,(0,0))
    #canvas.show()
    #canvas.save("kal6.jpg")








    def hexaganalator(_image):
        w,h= _image.size
        hradius=2*h/3
        wradius=w/2
        my_canvas=gz.Surface(w*2,h*2)
        leftvert=(w/4)
        rightvert=(w*3/4)

        _image=np.array(_image)
        center=  np.array([(w/2), h/2])
        pattern=(gz.ImagePattern(_image,pixel_zero=(0,0)))
        hexs=[(w/2,h/2),(w/2,-h/2),(w/2,3*h/2),(-w/4,0),(5*w/4,0),(-w/4,h),(5*w/4,h)      ]
        for _sw, _sh in hexs:
            hex_pat = gz.polyline(points=[(leftvert,0), (rightvert,0), (w,h/2), (rightvert,h),
                                        (leftvert,h),(0,h/2),(leftvert,0)], stroke_width=0, fill=pattern,xy=(_sw,_sh))
            hex_pat.draw(my_canvas)
            outp= my_canvas.get_npimage()



        #newIm = Image.fromarray(outp, "RGB")
       # newIm.show()
       # newIm.save("fullpattern17.jpg")
        return(outp)
    return hexaganalator(canvas)
#clip.fl(clipfilter).write_gif("kalvid15.gif")
#myclip=moviepy.video.fx.all.time_symmetrize(clip.fl(clipfilter))
myclip=moviepy.video.fx.all.speedx(clip.fl(clipfilter), factor=2.7)

#myclip=clip.fl(clipfilter)
myclip.write_videofile("mademovie7.mp4",audio=False)
del clip
myclip.reader.close()

# %%
''' 
A program to create Kaleidoscopic images or videos from imported images or videos.
'''

class Kaleido:
    """
    Class representation of the function for creating the image.
    """
    def __init__(self, url):
        '''
        initialize the file into a moviepy video.
        '''
        
        self.clip = mpy.VideoFileClip(url)
        self.clip=moviepy.video.fx.all.speedx(self.clip, factor=0.9)
        self.clip=moviepy.video.fx.all.time_symmetrize(self.clip)
        (self.h,self.w) ,self.d= self.clip.size,self.clip.duration
        
    
    def get_centre(self, centre):
        '''
        set the location that will be the centre of image selected, for use in GUI
        '''
    
        self.centre=np.array([centre])
        
    def set_height_of_sub_im(self, height_of_sub):
        """
        Changes the height of the image to be sected by user, for use in GUI
        """
        
        self.height_of_sub=height_of_sub
    
    def rotate_sub_im(self, rotation_of_im):
        """
        changes the angle of the image selected by the user, for use in GUI
        """
        self.rotation_of_sub=rotation_of_im
        
        
    def

# %%
import time
start_time = time.time()
main()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
help(clip.fl)
# Out:
# Help on method fl in module moviepy.Clip:
#
# fl(fun, apply_to=None, keep_duration=True) method of moviepy.video.io.VideoFileClip.VideoFileClip instance
#     General processing of a clip.
#
#     Returns a new Clip whose frames are a transformation
#     (through function ``fun``) of the frames of the current clip.
#
#     Parameters
#     -----------
#
#     fun
#       A function with signature (gf,t -> frame) where ``gf`` will
#       represent the current clip's ``get_frame`` method,
#       i.e. ``gf`` is a function (t->image). Parameter `t` is a time
#       in seconds, `frame` is a picture (=Numpy array) which will be
#       returned by the transformed clip (see examples below).
#
#     apply_to
#       Can be either ``'mask'``, or ``'audio'``, or
#       ``['mask','audio']``.
#       Specifies if the filter ``fl`` should also be applied to the
#       audio or the mask of the clip, if any.
#
#     keep_duration
#       Set to True if the transformation does not change the
#       ``duration`` of the clip.
#
#     Examples
#     --------
#
#     In the following ``newclip`` a 100 pixels-high clip whose video
#     content scrolls from the top to the bottom of the frames of
#     ``clip``.
#
#     >>> fl = lambda gf,t : gf(t)[int(t):int(t)+50, :]
#     >>> newclip = clip.fl(fl, apply_to='mask')

# %%
help(clip.fx)
# Out:
# Help on method fx in module moviepy.Clip:
#
# fx(func, *args, **kwargs) method of moviepy.video.io.VideoFileClip.VideoFileClip instance
#     Returns the result of ``func(self, *args, **kwargs)``.
#     for instance
#
#     >>> newclip = clip.fx(resize, 0.2, method='bilinear')
#
#     is equivalent to
#
#     >>> newclip = resize(clip, 0.2, method='bilinear')
#
#     The motivation of fx is to keep the name of the effect near its
#     parameters, when the effects are chained:
#
#     >>> from moviepy.video.fx import volumex, resize, mirrorx
#     >>> clip.fx( volumex, 0.5).fx( resize, 0.3).fx( mirrorx )
#     >>> # Is equivalent, but clearer than
#     >>> resize( volumex( mirrorx( clip ), 0.5), 0.3)
